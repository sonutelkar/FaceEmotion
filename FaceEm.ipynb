# %%
import matplotlib.pyplot as plt
import numpy as np 
import os

#Importing Deep Learning Libraries 
from keras.preprocessing.image import load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D, ZeroPadding2D
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf 
print(tf.config.list_physical_devices('GPU'))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
print(tf.test.is_built_with_cuda())
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Default GPU Device: /device:GPU:0
# True

# %% [markdown]
# <h1>Displaying Images</h1>

# %%
picture_size = 48
path = './images/'

# %%
expression = 'neutral'

plt.figure(figsize=(12,12))
plt.style.use('dark_background')
for i in range (1, 10):
    plt.subplot(3,3,i)
    imgname = os.listdir(f'{path}train/{expression}/')[i]
    img = load_img(path=f'{path}train/{expression}/{imgname}', 
                        target_size=(picture_size, picture_size))
    plt.imshow(img)
plt.show()

# %%
train_datagen = ImageDataGenerator()
train_generator = train_datagen.flow_from_directory(
    f'{path}train/',
    target_size=(picture_size,picture_size),
    color_mode="grayscale",
    classes=None,
    class_mode='categorical',
    batch_size=128,
    shuffle=True)
print(train_generator.class_indices)

val_datagen = ImageDataGenerator()
val_generator = val_datagen.flow_from_directory(    
    f'{path}/validation',
    target_size=(picture_size,picture_size),
    color_mode="grayscale",
    classes=None,
    class_mode='categorical',
    batch_size=128,
    shuffle=False,
    seed=100)
print(val_generator.class_indices)
# Out:
# Found 28821 images belonging to 7 classes.
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Found 7066 images belonging to 7 classes.
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %% [markdown]
# <h1>Defining The Model</h1>

# %%
num_classes = val_generator.num_classes

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(num_classes, activation='softmax'))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# <h1>Fitting The Model<h1>

# %%
# Setup simple early stopping & model checkpoint
es = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)
mc = ModelCheckpoint("./model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
check_LR = ReduceLROnPlateau(monitor='val_loss', factor = 0.2, patience=3, verbose=1, min_delta=0.0001)
callbacks_list = [es,mc,check_LR]

# %%
history = model.fit_generator(generator=train_generator, 
        steps_per_epoch= train_generator.n//train_generator.batch_size,
        validation_data=val_generator,
        validation_steps=val_generator.n//val_generator.batch_size,
        epochs=50, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.8318 - accuracy: 0.6883 - val_loss: 0.7268 - val_accuracy: 0.6349
#
# Epoch 00001: val_accuracy improved from -inf to 0.63494, saving model to ./model.h5
# Epoch 2/50
# 225/225 [==============================] - 34s 149ms/step - loss: 0.8129 - accuracy: 0.6972 - val_loss: 0.7190 - val_accuracy: 0.6372
#
# Epoch 00002: val_accuracy improved from 0.63494 to 0.63722, saving model to ./model.h5
# Epoch 3/50
# 225/225 [==============================] - 32s 144ms/step - loss: 0.7987 - accuracy: 0.7049 - val_loss: 0.9309 - val_accuracy: 0.6384
#
# Epoch 00003: val_accuracy improved from 0.63722 to 0.63837, saving model to ./model.h5
# Epoch 4/50
# 225/225 [==============================] - 32s 144ms/step - loss: 0.7890 - accuracy: 0.7059 - val_loss: 0.8312 - val_accuracy: 0.6411
#
# Epoch 00004: val_accuracy improved from 0.63837 to 0.64111, saving model to ./model.h5
# Epoch 5/50
# 225/225 [==============================] - 66s 295ms/step - loss: 0.7842 - accuracy: 0.7063 - val_loss: 0.6806 - val_accuracy: 0.6382
#
# Epoch 00005: val_accuracy did not improve from 0.64111
# Epoch 6/50
# 225/225 [==============================] - 101s 447ms/step - loss: 0.7784 - accuracy: 0.7131 - val_loss: 0.7775 - val_accuracy: 0.6392
#
# Epoch 00006: val_accuracy did not improve from 0.64111
# Epoch 7/50
# 225/225 [==============================] - 33s 144ms/step - loss: 0.7737 - accuracy: 0.7132 - val_loss: 1.1248 - val_accuracy: 0.6433
#
# Epoch 00007: val_accuracy improved from 0.64111 to 0.64327, saving model to ./model.h5
# Epoch 8/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.7733 - accuracy: 0.7098 - val_loss: 1.1270 - val_accuracy: 0.6472
#
# Epoch 00008: val_accuracy improved from 0.64327 to 0.64716, saving model to ./model.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 9/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.7709 - accuracy: 0.7123 - val_loss: 1.2225 - val_accuracy: 0.6477
#
# Epoch 00009: val_accuracy improved from 0.64716 to 0.64774, saving model to ./model.h5
# Epoch 10/50
# 225/225 [==============================] - 32s 143ms/step - loss: 0.7670 - accuracy: 0.7146 - val_loss: 1.1742 - val_accuracy: 0.6483
#
# Epoch 00010: val_accuracy improved from 0.64774 to 0.64831, saving model to ./model.h5
# Epoch 11/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.7633 - accuracy: 0.7154 - val_loss: 1.0577 - val_accuracy: 0.6466
#
# Epoch 00011: val_accuracy did not improve from 0.64831
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 12/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7604 - accuracy: 0.7191 - val_loss: 1.2000 - val_accuracy: 0.6472
#
# Epoch 00012: val_accuracy did not improve from 0.64831
# Epoch 13/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.7659 - accuracy: 0.7144 - val_loss: 1.0880 - val_accuracy: 0.6474
#
# Epoch 00013: val_accuracy did not improve from 0.64831
# Epoch 14/50
# 225/225 [==============================] - 32s 143ms/step - loss: 0.7634 - accuracy: 0.7189 - val_loss: 1.1805 - val_accuracy: 0.6480
#
# Epoch 00014: val_accuracy did not improve from 0.64831
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 15/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7713 - accuracy: 0.7119 - val_loss: 1.0204 - val_accuracy: 0.6486
#
# Epoch 00015: val_accuracy improved from 0.64831 to 0.64860, saving model to ./model.h5
# Epoch 16/50
# 225/225 [==============================] - 32s 142ms/step - loss: 0.7607 - accuracy: 0.7184 - val_loss: 1.0074 - val_accuracy: 0.6466
#
# Epoch 00016: val_accuracy did not improve from 0.64860
# Epoch 17/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7660 - accuracy: 0.7191 - val_loss: 0.8419 - val_accuracy: 0.6454
#
# Epoch 00017: val_accuracy did not improve from 0.64860
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 18/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7635 - accuracy: 0.7165 - val_loss: 0.8999 - val_accuracy: 0.6446
#
# Epoch 00018: val_accuracy did not improve from 0.64860
# Epoch 19/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7683 - accuracy: 0.7177 - val_loss: 1.0991 - val_accuracy: 0.6451
#
# Epoch 00019: val_accuracy did not improve from 0.64860
# Epoch 20/50
# 225/225 [==============================] - 32s 140ms/step - loss: 0.7647 - accuracy: 0.7156 - val_loss: 1.0953 - val_accuracy: 0.6476
#
# Epoch 00020: val_accuracy did not improve from 0.64860
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 21/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7635 - accuracy: 0.7153 - val_loss: 0.8706 - val_accuracy: 0.6451
#
# Epoch 00021: val_accuracy did not improve from 0.64860
# Epoch 22/50
# 225/225 [==============================] - 32s 140ms/step - loss: 0.7704 - accuracy: 0.7137 - val_loss: 1.0227 - val_accuracy: 0.6440
#
# Epoch 00022: val_accuracy did not improve from 0.64860
# Epoch 23/50
# 225/225 [==============================] - 32s 141ms/step - loss: 0.7652 - accuracy: 0.7181 - val_loss: 0.9482 - val_accuracy: 0.6460
#
# Epoch 00023: val_accuracy did not improve from 0.64860
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 24/50
# 225/225 [==============================] - 32s 140ms/step - loss: 0.7645 - accuracy: 0.7144 - val_loss: 1.0029 - val_accuracy: 0.6473
#
# Epoch 00024: val_accuracy did not improve from 0.64860
# Epoch 25/50
# 225/225 [==============================] - 31s 140ms/step - loss: 0.7705 - accuracy: 0.7141 - val_loss: 0.7868 - val_accuracy: 0.6462
#
# Epoch 00025: val_accuracy did not improve from 0.64860
# Epoch 26/50
# 225/225 [==============================] - 31s 140ms/step - loss: 0.7657 - accuracy: 0.7164 - val_loss: 0.4592 - val_accuracy: 0.6450
#
# Epoch 00026: val_accuracy did not improve from 0.64860
# Epoch 27/50
# 225/225 [==============================] - 34s 149ms/step - loss: 0.7659 - accuracy: 0.7156 - val_loss: 0.3837 - val_accuracy: 0.6415
#
# Epoch 00027: val_accuracy did not improve from 0.64860
# Epoch 28/50
# 225/225 [==============================] - 31s 139ms/step - loss: 0.7618 - accuracy: 0.7169 - val_loss: 0.5679 - val_accuracy: 0.6418
#
# Epoch 00028: val_accuracy did not improve from 0.64860
# Epoch 29/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7622 - accuracy: 0.7155 - val_loss: 0.4412 - val_accuracy: 0.6418
#
# Epoch 00029: val_accuracy did not improve from 0.64860
# Epoch 30/50
# 225/225 [==============================] - 33s 145ms/step - loss: 0.7722 - accuracy: 0.7163 - val_loss: 0.3666 - val_accuracy: 0.6415
#
# Epoch 00030: val_accuracy did not improve from 0.64860
# Epoch 31/50
# 225/225 [==============================] - 33s 145ms/step - loss: 0.7672 - accuracy: 0.7148 - val_loss: 0.4164 - val_accuracy: 0.6413
#
# Epoch 00031: val_accuracy did not improve from 0.64860
# Epoch 32/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7653 - accuracy: 0.7199 - val_loss: 0.2385 - val_accuracy: 0.6415
#
# Epoch 00032: val_accuracy did not improve from 0.64860
# Epoch 33/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7653 - accuracy: 0.7144 - val_loss: 0.5641 - val_accuracy: 0.6404
#
# Epoch 00033: val_accuracy did not improve from 0.64860
# Epoch 34/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7689 - accuracy: 0.7166 - val_loss: 0.5361 - val_accuracy: 0.6423
#
# Epoch 00034: val_accuracy did not improve from 0.64860
# Epoch 35/50
# 225/225 [==============================] - 33s 145ms/step - loss: 0.7667 - accuracy: 0.7162 - val_loss: 0.3938 - val_accuracy: 0.6425
#
# Epoch 00035: val_accuracy did not improve from 0.64860
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 36/50
# 225/225 [==============================] - 33s 147ms/step - loss: 0.7741 - accuracy: 0.7108 - val_loss: 0.3273 - val_accuracy: 0.6417
#
# Epoch 00036: val_accuracy did not improve from 0.64860
# Epoch 37/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7628 - accuracy: 0.7178 - val_loss: 0.5922 - val_accuracy: 0.6414
#
# Epoch 00037: val_accuracy did not improve from 0.64860
# Epoch 38/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7682 - accuracy: 0.7136 - val_loss: 0.4160 - val_accuracy: 0.6428
#
# Epoch 00038: val_accuracy did not improve from 0.64860
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 39/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7654 - accuracy: 0.7151 - val_loss: 0.9433 - val_accuracy: 0.6415
#
# Epoch 00039: val_accuracy did not improve from 0.64860
# Epoch 40/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7661 - accuracy: 0.7145 - val_loss: 1.4505 - val_accuracy: 0.6453
#
# Epoch 00040: val_accuracy did not improve from 0.64860
# Epoch 41/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7644 - accuracy: 0.7188 - val_loss: 1.4635 - val_accuracy: 0.6511
#
# Epoch 00041: val_accuracy improved from 0.64860 to 0.65105, saving model to ./model.h5
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 42/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7583 - accuracy: 0.7157 - val_loss: 1.4768 - val_accuracy: 0.6513
#
# Epoch 00042: val_accuracy improved from 0.65105 to 0.65134, saving model to ./model.h5
# Epoch 43/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7686 - accuracy: 0.7171 - val_loss: 1.4764 - val_accuracy: 0.6508
#
# Epoch 00043: val_accuracy did not improve from 0.65134
# Epoch 44/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7654 - accuracy: 0.7163 - val_loss: 1.5152 - val_accuracy: 0.6519
#
# Epoch 00044: val_accuracy improved from 0.65134 to 0.65192, saving model to ./model.h5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 45/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7665 - accuracy: 0.7170 - val_loss: 1.4611 - val_accuracy: 0.6515
#
# Epoch 00045: val_accuracy did not improve from 0.65192
# Epoch 46/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7634 - accuracy: 0.7198 - val_loss: 1.5675 - val_accuracy: 0.6508
#
# Epoch 00046: val_accuracy did not improve from 0.65192
# Epoch 47/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7719 - accuracy: 0.7131 - val_loss: 1.8805 - val_accuracy: 0.6519
#
# Epoch 00047: val_accuracy did not improve from 0.65192
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 48/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7631 - accuracy: 0.7147 - val_loss: 1.5691 - val_accuracy: 0.6519
#
# Epoch 00048: val_accuracy did not improve from 0.65192
# Epoch 49/50
# 225/225 [==============================] - 33s 146ms/step - loss: 0.7624 - accuracy: 0.7180 - val_loss: 1.3073 - val_accuracy: 0.6493
#
# Epoch 00049: val_accuracy did not improve from 0.65192
# Epoch 50/50
# 225/225 [==============================] - 33s 147ms/step - loss: 0.7657 - accuracy: 0.7182 - val_loss: 1.2349 - val_accuracy: 0.6486
#
# Epoch 00050: val_accuracy did not improve from 0.65192
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.

# %%
plt.figure(figsize=(20,8))
plt.style.use('dark_background')
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.ylabel('Loss', fontsize=16)
plt.legend(loc='best')
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=16)
plt.legend(loc='best')
plt.show()
